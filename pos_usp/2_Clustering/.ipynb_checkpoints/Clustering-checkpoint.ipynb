# %% [markdown]
# ## Implementação do cluster hierárquico no python

# %% [markdown]
# Libraries
#
# [Hierarchical clustering](https://docs.scipy.org/doc/scipy/reference/cluster.hierarchy.html)

# %%
# importando bibliotecas
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage, average, single, complete
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler

# %%
x=[20,  27,  21,  37,  46, 53, 55,  47,  52,  32,  39,  41,  39,  48,  48]  
y=[1000,1200,2900,1850,900,950,2000,2100,3000,5900,4100,5100,7000,5000,6500]

plt.scatter(x,y)

# %%
base = np.array([[20,1000],[27,1200],[21,2900],[37,1850],[46,900],
                 [53,950],[55,2000],[47,2100],[52,3000],[32,5900],
                 [39,4100],[41,5100],[39,7000],[48,5000],[48,6500]])

# %%
base
# Out:
# array([[  20, 1000],
#        [  27, 1200],
#        [  21, 2900],
#        [  37, 1850],
#        [  46,  900],
#        [  53,  950],
#        [  55, 2000],
#        [  47, 2100],
#        [  52, 3000],
#        [  32, 5900],
#        [  39, 4100],
#        [  41, 5100],
#        [  39, 7000],
#        [  48, 5000],
#        [  48, 6500]])

# %% [markdown]
# scipy.cluster.hierarchy.linkage(y, method='single', metric='euclidean', optimal_ordering=False).
#
# Perform hierarchical/agglomerative clustering.
#
# [scipy.cluster.hierarchy.linkage](https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.linkage.html#scipy.cluster.hierarchy.linkage)

# %%
# gerando o dendograma

scaler = StandardScaler()
base = scaler.fit_transform(base)

dendrograma = dendrogram(linkage(base, method = 'ward'))

# Títulos
plt.title('Dendrograma')
plt.xlabel('Pessoas')
plt.ylabel('Distância Euclidiana')

# 
hc = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage = 'ward')
previsoes = hc.fit_predict(base)

# %%
# A seguir podemos criar o scatterplot dividindo os pontos em 3 clusters:    

plt.scatter(base[previsoes == 0, 0], base[previsoes == 0, 1], s = 50, c = 'red', label = 'Cluster 1')
plt.scatter(base[previsoes == 1, 0], base[previsoes == 1, 1], s = 50, c = 'blue', label = 'Cluster 2')
plt.scatter(base[previsoes == 2, 0], base[previsoes == 2, 1], s = 50, c = 'green', label = 'Cluster 3')

plt.xlabel('Idade')
plt.ylabel('Salário')
plt.legend()

# %% [markdown]
# ## Exercício de Aula

# %%
df = pd.read_csv('MCDONALDS.csv', sep=';')

# %%
df.head()
# Out:
#            Lanche  Valor Energetico  Carboidratos  Proteinas Gorduras Totais  \
# 0         Big Mac               504            41         25              27
# 1       Big Tasty               843            45         41              55
# 2       Quarterao               558            36         31              32
# 3  Mcnifico Bacon               625            38         34              37
# 4  Cheddar McMelt               507            33         29              29
#
#   Gorduras Saturadas Gorduras Trans   Colesterol Fibra Alimentar  Sodio  \
# 0                 12             0,5          54             3,5    960
# 1                 24             1,7         104             5,1   1511
# 2                 16             1,3          86             3,6   1216
# 3                 16             1,3          95             3,9   1255
# 4                 14             1,2          81             2,9    819
#
#    Calcio Ferro
# 0     162   6,5
# 1     381   8,2
# 2     275    10
# 3     209    11
# 4     199    10

# %%
df = df.set_index('Lanche')

df.head()
# Out:
#                 Valor Energetico  Carboidratos  Proteinas Gorduras Totais  \
# Lanche
# Big Mac                      504            41         25              27
# Big Tasty                    843            45         41              55
# Quarterao                    558            36         31              32
# Mcnifico Bacon               625            38         34              37
# Cheddar McMelt               507            33         29              29
#
#                Gorduras Saturadas Gorduras Trans   Colesterol Fibra Alimentar  \
# Lanche
# Big Mac                        12             0,5          54             3,5
# Big Tasty                      24             1,7         104             5,1
# Quarterao                      16             1,3          86             3,6
# Mcnifico Bacon                 16             1,3          95             3,9
# Cheddar McMelt                 14             1,2          81             2,9
#
#                 Sodio  Calcio Ferro
# Lanche
# Big Mac           960     162   6,5
# Big Tasty        1511     381   8,2
# Quarterao        1216     275    10
# Mcnifico Bacon   1255     209    11
# Cheddar McMelt    819     199    10

# %%
df = df[['Valor Energetico', 'Carboidratos']]

df.head()
# Out:
#                 Valor Energetico  Carboidratos
# Lanche
# Big Mac                      504            41
# Big Tasty                    843            45
# Quarterao                    558            36
# Mcnifico Bacon               625            38
# Cheddar McMelt               507            33

# %%
# https://seaborn.pydata.org/examples/different_scatter_variables.html

x = df['Valor Energetico']
y = df['Carboidratos']

plt.scatter(x,y)

# %%
# x and y given as array_like objects
import plotly.express as px

fig = px.scatter(df['Valor Energetico'], df['Carboidratos'])
fig.show()
# Out:
# <div>                            <div id="8251620b-c635-4257-b0b4-403b292fdaa1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8251620b-c635-4257-b0b4-403b292fdaa1")) {                    Plotly.newPlot(                        "8251620b-c635-4257-b0b4-403b292fdaa1",                        [{"hovertemplate": "x=%{x}<br>Lanche=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "h", "showlegend": false, "type": "scatter", "x": [41, 45, 36, 38, 33, 38, 40, 33, 52, 44, 54, 46, 54, 46, 32, 31, 29, 33, 30, 34, 45, 31, 57, 56, 56], "xaxis": "x", "y": ["Big Mac", "Big Tasty", "Quarterao", "Mcnifico Bacon", "Cheddar McMelt", "McFish", "McChicken", "McChicken Jr", "Chicken Classic Crispy", "Chicken Classic Grill", "Chicken Club Crispy", "Chicken Club Grill", "Chicken Lemon Crispy", "Chicken Lemon Grill", "Cheeseburger", "Hamburger", "Wrap Grill Maionese", "Wrap Crispy Maionese", "Wrap Grill Lemon", "Wrap Crispy Lemon", "Chicken Bacon Crispy", "Chicken Bacon Grill", "Angus Bacon", "Angus Deluxe", "CBO "], "yaxis": "y"}],                        {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#4603 ...

# %%
#Padronizar variaveis

scaler = StandardScaler()
base = scaler.fit_transform(df)

# %%
base
# Out:
# array([[ 0.06101153, -0.03943199],
#        [ 2.0808268 ,  0.3987012 ],
#        [ 0.38275202, -0.58709847],
#        [ 0.78194854, -0.36803187],
#        [ 0.078886  , -0.91569835],
#        [-0.71950706, -0.36803187],
#        [-0.23689633, -0.14896528],
#        [-0.93400072, -0.91569835],
#        [-0.02240267,  1.16543427],
#        [-0.40968289,  0.2891679 ],
#        [ 0.69257619,  1.38450086],
#        [ 0.30529597,  0.50823449],
#        [-0.23689633,  1.38450086],
#        [-0.62417654,  0.50823449],
#        [-1.09487096, -1.02523165],
#        [-1.41065329, -1.13476495],
#        [-0.91612624, -1.35383154],
#        [-0.72546521, -0.91569835],
#        [-1.11870359, -1.24429824],
#        [-0.92804256, -0.80616506],
#        [ 0.12655126,  0.3987012 ],
#        [-0.40968289, -1.13476495],
#        [ 2.18807363,  1.71310075],
#        [ 2.19998995,  1.60356745],
#        [ 0.88919537,  1.60356745]])

# %%
#calcular as distancias da matriz utilizando a distancia euclidiana

dendrograma = dendrogram(linkage(base, method = 'ward'))

# Títulos
plt.title('Dendrograma')
plt.xlabel('Lanches')
plt.ylabel('Distância Euclidiana')

# 
hc = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage = 'ward')
previsoes = hc.fit_predict(base)

# %%
# Calcular o Cluster: metodos disponiveis "average", "single", "complete" e "ward.D"

dendrograma = dendrogram(linkage(base, method = 'average'))

# Títulos
plt.title('Dendrograma')
plt.xlabel('Lanches')
plt.ylabel('Distância Euclidiana')


hc = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage = 'average')
previsoes = hc.fit_predict(base)

# %%
dendrograma = dendrogram(linkage(base, method = 'single'))

# Títulos
plt.title('Dendrograma')
plt.xlabel('Lanches')
plt.ylabel('Distância Euclidiana')


hc = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage = 'single')
previsoes = hc.fit_predict(base)

# %%
# Calcular o Cluster: metodos disponiveis "average", "single", "complete" e "ward.D"

dendrograma = dendrogram(linkage(base, method = 'complete'))

# Títulos
plt.title('Dendrograma')
plt.xlabel('Lanches')
plt.ylabel('Distância Euclidiana')


hc = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage = 'complete')
previsoes = hc.fit_predict(base)

# %%
# https://medium.com/pizzadedados/kmeans-e-metodo-do-cotovelo-94ded9fdf3a9

from sklearn.cluster import KMeans

def calculate_wcss(data):
    wcss = []
    for n in range(2, 21):
        kmeans = KMeans(n_clusters=n)
        kmeans.fit(X=data)
        wcss.append(kmeans.inertia_)

    return wcss

# %%
calculate_wcss(base)
# Out:
# [20.338011301110086,
#  10.760793325177765,
#  6.933584898301377,
#  4.805639246369031,
#  3.739312301180956,
#  2.84393692772512,
#  2.161683627048867,
#  1.6861705600550059,
#  1.288265882818212,
#  0.895992755300513,
#  0.6846970448467814,
#  0.5378343808657519,
#  0.4350908244151299,
#  0.33243105732427036,
#  0.28205774005501505,
#  0.22582987369056745,
#  0.17883102333227152,
#  0.1318321729739756,
#  0.08850753500938095]

# %%
# Cria a Curva de Cotovelo para encontrar o Numero Ideal de Clusters
# https://www.kaggle.com/eriveltonguedes/7-clusteriza-o-k-means-erivelton

from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)
    
# Mostra o Gráfico
plt.plot(range(1, 11), wcss)
plt.title('Curva de Cotovelo')
plt.xlabel('Numero de Clusters')
plt.ylabel('WCSS') #within cluster sum of squares
plt.show()

# %% [markdown]
# [continua no próximo fim de semana]
